# %% [markdown]
# # Nested Cross Validation for Logistic Regression
#
# ## Setup

# %%
import numpy as np

from cv import grid, nested_cv
from train.logistic_regression import LRTrainer

# %%
lr_trainer = LRTrainer()

# %% [markdown]
# ## Penalties

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# `sklearn`'s library code for logistic regression includes many different optimizers.
# Unfortunately, only two of the optimizers work for LASSO (`l1` penalty):
# - `liblinear` only works for one-versus-rest regression
# - `saga` is slow
#
# `saga` is the only optimizer that can handle the `elasticnet` penalty; it is again too slow.
#
# By elimination, we must use `l2` regularization.
# The default `lbfgs` optimizer works well for this.
#
# In addition to various degrees of `l2` regularization, we also consider no regularization at all (`None`).
#
# For reasonable steps, we take inspiration from [`LogisticRegressionCV`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegressionCV.html) which uses 10 geometrically-spaced increments between `1e-4` and `1e4`.

# %%
base_configs = [
    {
        "penalty": ["l2"],
        "C": np.power(10, np.linspace(start=-4, stop=4, num=10)),
    },
    {
        "penalty": [None],
    }
]

# %% [markdown]
# ## One-Versus-Rest (OVR) Logistic Regression

# %%
ovr_configs = list(
    config
    for base_config in base_configs
    for config in grid(multi_class=["ovr"], **base_config)
)
nested_cv(lr_trainer, ovr_configs, "../models/lr/ovr/", n_folds=5)
# Out:
# Outer CV: 1
#   Inner CV: 1
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.384615	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.798817	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.923077	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.976331	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.988166	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.988166	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.988166	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.988166	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.988166	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.976331	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 2
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.343195	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.786982	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.881657	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.923077	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.946746	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.952663	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.958580	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.958580	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.958580	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.958580	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 3
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.360947	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.763314	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.893491	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.946746	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.970414	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.988166	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.994083	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.994083	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.994083	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.970414	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 4
#     1/11	0.125000	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.321429	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.726190	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.857143	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.928571	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.952381	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.958333	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.958333	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.958333	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.958333	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.946429	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 5
#     1/11	0.130952	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.357143	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.720238	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.910714	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.940476	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.940476	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.946429	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.964286	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.964286	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.964286	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.934524	{'penalty': None, 'multi_class': 'ovr'}
# Outer CV: 2
#   Inner CV: 1
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.360947	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.763314	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.917160	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.970414	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.988166	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.988166	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.988166	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.988166	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.988166	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.982249	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 2
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.349112	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.786982	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.881657	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.917160	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.940828	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.970414	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.970414	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970414	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.970414	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.934911	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 3
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.378698	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.739645	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.899408	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.928994	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.970414	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.976331	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.970414	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970414	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.976331	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.976331	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 4
#     1/11	0.125000	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.315476	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.714286	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.857143	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.922619	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.946429	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.958333	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.958333	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.964286	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.964286	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.940476	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 5
#     1/11	0.125000	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.339286	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.779762	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.863095	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.922619	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.958333	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.964286	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.970238	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970238	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.970238	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.946429	{'penalty': None, 'multi_class': 'ovr'}
# Outer CV: 3
#   Inner CV: 1
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.355030	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.739645	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.881657	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.923077	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.964497	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.976331	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.976331	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.976331	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.976331	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.946746	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 2
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.337278	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.763314	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.875740	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.946746	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.982249	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.982249	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.982249	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.982249	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.982249	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.982249	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 3
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.378698	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.751479	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.875740	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.940828	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.970414	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.970414	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.970414	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970414	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.976331	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.976331	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 4
#     1/11	0.130952	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.345238	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.738095	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.892857	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.952381	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.976190	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.988095	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.988095	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.988095	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.988095	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.970238	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 5
#     1/11	0.125000	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.333333	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.761905	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.863095	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.928571	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.934524	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.958333	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.958333	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.958333	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.964286	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.928571	{'penalty': None, 'multi_class': 'ovr'}
# Outer CV: 4
#   Inner CV: 1
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.355030	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.763314	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.881657	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.940828	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.964497	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.970414	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.970414	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970414	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.970414	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.964497	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 2
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.325444	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.745562	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.905325	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.952663	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.970414	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.982249	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.988166	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.988166	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.988166	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.958580	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 3
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.372781	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.763314	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.893491	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.934911	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.958580	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.970414	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.970414	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970414	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.970414	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.952663	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 4
#     1/11	0.130952	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.333333	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.779762	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.892857	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.946429	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.958333	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.958333	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.958333	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.958333	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.964286	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.946429	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 5
#     1/11	0.125000	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.357143	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.779762	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.880952	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.946429	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.976190	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.982143	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.982143	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.982143	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.982143	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.976190	{'penalty': None, 'multi_class': 'ovr'}
# Outer CV: 5
#   Inner CV: 1
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.355030	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.781065	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.923077	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.952663	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.970414	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.958580	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.958580	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.958580	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.958580	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.946746	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 2
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.349112	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.751479	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.869822	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.952663	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.964497	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.964497	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.964497	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970414	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.970414	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.970414	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 3
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.390533	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.721893	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.857988	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.928994	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.964497	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.976331	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.982249	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.982249	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.988166	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.976331	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 4
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.331361	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.745562	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.869822	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.952663	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.970414	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.970414	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.970414	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.970414	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.976331	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.970414	{'penalty': None, 'multi_class': 'ovr'}
#   Inner CV: 5
#     1/11	0.125000	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'ovr'}
#     2/11	0.357143	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'ovr'}
#     3/11	0.750000	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'ovr'}
#     4/11	0.863095	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'ovr'}
#     5/11	0.898810	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'ovr'}
#     6/11	0.934524	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'ovr'}
#     7/11	0.940476	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'ovr'}
#     8/11	0.940476	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'ovr'}
#     9/11	0.946429	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'ovr'}
#     10/11	0.964286	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'ovr'}
#     11/11	0.934524	{'penalty': None, 'multi_class': 'ovr'}
# 0.9772376438727151

# %% [markdown]
# ## Multinomial Logistic Regression

# %%
multinomial_configs = list(
    config
    for base_config in base_configs
    for config in grid(multi_class=["multinomial"], **base_config)
)
nested_cv(lr_trainer, multinomial_configs, "../models/lr/multinomial/", n_folds=5)
# Out:
# Outer CV: 1
#   Inner CV: 1
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.390533	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.810651	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.934911	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0.970414	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     6/11	0.982249	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     7/11	0.982249	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     8/11	0.982249	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     9/11	0.982249	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     10/11	0.976331	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     11/11	0.964497	{'penalty': None, 'multi_class': 'multinomial'}
#   Inner CV: 2
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.384615	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.792899	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.881657	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0.923077	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     6/11	0.934911	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     7/11	0.946746	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     8/11	0.952663	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     9/11	0.964497	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     10/11	0.964497	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     11/11	0.934911	{'penalty': None, 'multi_class': 'multinomial'}
#   Inner CV: 3
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.366864	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.792899	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.893491	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0.940828	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     6/11	0.952663	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     7/11	0.970414	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     8/11	0.970414	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     9/11	0.976331	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     10/11	0.982249	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     11/11	0.928994	{'penalty': None, 'multi_class': 'multinomial'}
#   Inner CV: 4
#     1/11	0.125000	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.345238	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.744048	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.892857	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0.928571	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     6/11	0.958333	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     7/11	0.958333	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     8/11	0.958333	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     9/11	0.958333	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     10/11	0.958333	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     11/11	0.934524	{'penalty': None, 'multi_class': 'multinomial'}
#   Inner CV: 5
#     1/11	0.130952	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.380952	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.755952	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.898810	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0.928571	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     6/11	0.922619	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     7/11	0.928571	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     8/11	0.934524	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     9/11	0.934524	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     10/11	0.934524	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     11/11	0.904762	{'penalty': None, 'multi_class': 'multinomial'}
# Outer CV: 2
#   Inner CV: 1
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.366864	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.781065	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.923077	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0.958580	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     6/11	0.970414	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     7/11	0.976331	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     8/11	0.976331	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     9/11	0.976331	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     10/11	0.976331	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     11/11	0.952663	{'penalty': None, 'multi_class': 'multinomial'}
#   Inner CV: 2
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.390533	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.804734	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.875740	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0.917160	{'C': 0.3593813663804626, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     6/11	0.940828	{'C': 2.782559402207126, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     7/11	0.946746	{'C': 21.54434690031882, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     8/11	0.952663	{'C': 166.81005372000558, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     9/11	0.964497	{'C': 1291.5496650148827, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     10/11	0.964497	{'C': 10000.0, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     11/11	0.934911	{'penalty': None, 'multi_class': 'multinomial'}
#   Inner CV: 3
#     1/11	0.130178	{'C': 0.0001, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     2/11	0.390533	{'C': 0.000774263682681127, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     3/11	0.745562	{'C': 0.005994842503189409, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     4/11	0.905325	{'C': 0.046415888336127774, 'penalty': 'l2', 'multi_class': 'multinomial'}
#     5/11	0